# %% [markdown]
# ## **2. Variables y Tipos de Datos Simples**

# %% [markdown]
# ### 🐍 Bienvenidos al mundo de Python 🚀
# - Cada línea de código que escribes es una nueva habilidad que desarrollas.
# - No tengas miedo de equivocarte: los errores también enseñan.
# - Programar es crear, imaginar y resolver problemas.
# - Hoy empiezas como estudiante, mañana podrás crear tus propias aplicaciones, videojuegos, robots o proyectos tecnológicos.
#
# *¡Confía en ti y disfruta el proceso de aprender Python!* 💡

# %%
# Nuestro primer programa en Python
print('Hola Mundo Python!')

# Tambien podemos usar comillas dobles
print("Bienvenidos al mundo de la programación")

# Podemos usar comillas triples para escribir texto en varias líneas
print('''Este es un programa de ejemplo
para mostrar cómo usar comillas triples
en Python.''')
# Out:
# Hola Mundo Python!
# Bienvenidos al mundo de la programación
# Este es un programa de ejemplo
# para mostrar cómo usar comillas triples
# en Python.

# %% [markdown]
# Cuando ejecutas el código anterior que se trata de un programa Python. Tu editor lo ejecuta a través del intérprete de Python, que lee el programa y determina el significado de cada palabra. Por ejemplo, cuando el intérprete encuentra la palabra `print` seguida de paréntesis, imprime en pantalla el contenido dentro de ellos.
#
# Mientras escribes tus programas, el editor resalta diferentes partes del código de distintas maneras. Por ejemplo, reconoce que `print()` es el nombre de una función y la muestra en un color. Reconoce que "¡Hola mundo Python!" no es código Python y la muestra en otro color. Esta función se llama resaltado de sintaxis y resulta muy útil al empezar a escribir tus propios programas.

# %% [markdown]
# ### **2.1 Variables**

# %% [markdown]
# Vamos a usar una variable en nuestro primer programa:

# %%
mensaje = 'Hola Mundo Python!'
print(mensaje)
# Out:
# Hola Mundo Python!

# %% [markdown]
# Se añadió una variable llamada `mensaje`. Cada variable está asociada a un valor, que es la información que contiene. En este caso, el valor es el texto "¡Hola mundo Python!".

# %% [markdown]
# Ampliemos nuestro programa para imprimir un segundo mensaje:

# %%
# Añadimos un segundo mensaje

mensaje = 'Hola Mundo Python!'
print(mensaje)

mensaje = 'Dios te Bendiga!'
print(mensaje)
# Out:
# Hola Mundo Python!
# Dios te Bendiga!

# %% [markdown]
# Puedes cambiar el valor de una variable en tu programa en cualquier momento, y Python siempre mantendrá un registro de su valor actual.

# %% [markdown]
# #### **2.1.1 Nombrando y Usando Variables**

# %% [markdown]
# Al usar variables en Python, es necesario seguir algunas reglas y pautas para evitar errores; otras pautas simplemente te ayudarán a escribir código más fácil de leer y comprender. Asegúrate de tener en cuenta las siguientes reglas al trabajar con variables:
#
# - Los nombres de las variables solo pueden contener letras, números y guiones bajos. Pueden comenzar con una letra o un guion bajo, pero no con un número. Por ejemplo, puedes llamar a una variable `mensaje_1`, pero no `1_mensaje`.
#
# - No se permiten espacios en los nombres de las variables, pero se pueden usar guiones bajos para separar palabras. Por ejemplo, `saludo_mensaje` funciona, pero `saludo mensaje` provocará errores.
#
# - Evita usar *palabras clave* y nombres de funciones de Python como nombres de variables. Por ejemplo, no uses la palabra `print` como nombre de variable; Python la ha reservado para un propósito programático específico.
#
# - Los nombres de las variables deben ser cortos pero descriptivos. Por ejemplo, `nombre` es mejor que `n`, `nombre_estudiante` es mejor que `s_n`, y `longitud_nombre` es mejor que `longitud_del_nombre_de_la_persona`.
#
# - Tenga cuidado al usar la letra *l* minúscula y la letra *O* mayúscula, ya que podrían confundirse con los números *1* y *0*.

# %% [markdown]
# ##### *Palabras claves de Python*
#
# <img src="imgs/keywords_python.jpeg" width="500" alt="Palabras Clave Python">

# %% [markdown]
# #### **2.1.2 Cómo Evitar Errores de Nombres al Usar Variables**

# %% [markdown]
# Los errores al escribir nombres de variables son muy comunes en programación, especialmente al comenzar a aprender Python. Cuando una variable se escribe incorrectamente, el programa genera un error porque Python no reconoce ese nombre. Sin embargo, el intérprete de Python ayuda al programador mostrando un “rastreo de pila” o traceback, que indica en qué parte del código ocurrió el problema. Aprender a leer estos mensajes de error es importante para identificar y corregir errores de manera rápida y eficiente.

# %%
# En este programa se introduce un error a propósito en el nombre de la variable
mensaje = 'Hola, Sigue aprendiendo Python!'
print(mensje)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # En este programa se introduce un error a propósito en el nombre de la variable
#       2 mensaje = 'Hola, Sigue aprendiendo Python!'
# ----> 3 print(mensje)
#
# NameError: name 'mensje' is not defined

# %% [markdown]
# La salida indica que se produjo un error en la línea 2 de la celda. El intérprete muestra esta línea 2 para ayudarnos a detectar el error rápidamente e indica qué tipo de error encontró. En este caso, se detectó un error de nombre e informa que la variable que se imprime, `mensje`, no está definida.
#
# Python no puede identificar el nombre de variable proporcionado. Un error de nombre generalmente significa que olvidamos asignar un valor a la variable antes de usarla o que cometimos un error ortográfico al escribir su nombre. Si Python encuentra un nombre de variable similar al que no reconoce, preguntará si ese es el nombre que se pretendía usar.
#
# En este ejemplo, omitimos la letra *s* en el nombre de la variable `mensaje` en la segunda línea. El intérprete de Python no revisa la ortografía del código, pero sí se asegura de que los nombres de las variables se escriban de forma consistente.

# %% [markdown]
# #### **2.1.3 Inténtalo Tú Mismo!**

# %% [markdown]
# Escribe un programa independiente para cada uno de los siguientes ejercicios.

# %% [markdown]
# ##### *Ejercicio 2-1. Mensaje simple:*
# Asigna un mensaje a una variable y luego imprímelo.

# %%
# Mensaje Simple

# %% [markdown]
# ##### *Ejercicio 2-2. Mensajes simples:*
# Asigna un mensaje a una variable y luego imprímelo. Después, cambia el valor de la variable a un nuevo mensaje e imprímelo

# %%
# Mensajes Simples

# %% [markdown]
# ### **2.2 Cadenas**

# %% [markdown]
# Los programas organizan la información en diferentes tipos de datos para poder procesarla y utilizarla de forma útil. El primer dato que analizaremos es la cadena de caracteres.
#
# * **¿Qué es una cadena?** La cadena de caracteres (*string*) es una secuencia de texto que, a pesar de su aparente simplicidad, es muy versátil y tiene múltiples aplicaciones.
# * **Regla en Python:** En este lenguaje, cualquier elemento que esté encerrado entre **comillas simples (`' '`) o dobles (`" "`)** se considera automáticamente una cadena de caracteres.

# %%
"Esto es una Cadena"
'Esto también es una Cadena'

# %% [markdown]
# #### **2.2.1 Cambiar Mayúsculas y Minúsculas en una Cadena con Métodos**

# %% [markdown]
# Una de las tareas más sencillas que puedes realizar con cadenas es cambiar las mayúsculas y minúsculas de las palabras. Observa el siguiente código e intenta comprender qué sucede:

# %%
nombre = "ada lovelace"
print(nombre.title())
# Out:
# Ada Lovelace

# %% [markdown]
# En este ejemplo, la variable `name` se refiere a la cadena en minúsculas "ada lovelace". El método `title()` aparece después de la variable en la llamada a `print()`. Un método es una acción que Python puede realizar sobre un dato. El punto (.) después de `name` en `name.title()` le indica a Python que el método `title()` actúe sobre la variable `name`.
#
# Cada método va seguido de un paréntesis, ya que a menudo necesita información adicional para funcionar. Esta información se proporciona dentro de los paréntesis. La función `title()` no necesita información adicional, por lo que sus paréntesis están vacíos.
#
# También hay otros métodos útiles disponibles para manejar mayúsculas y minúsculas. Por ejemplo, puedes convertir una cadena a mayúsculas o minúsculas de la siguiente manera:

# %%
nombre = "Ada Lovelace"
print(nombre.upper())
print(nombre.lower())
# Out:
# ADA LOVELACE
# ada lovelace

# %% [markdown]
# #### **2.2.2 Uso de Variables en Cadenas de Texto**

# %% [markdown]
# En algunas situaciones, querrás usar el valor de una variable dentro de una cadena. Por ejemplo, podrías usar dos variables para representar un nombre y un apellido, respectivamente, y luego combinar esos valores para mostrar el nombre completo de una persona:

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = f'{first_name} {last_name}'
print(full_name)
# Out:
# ada lovelace

# %% [markdown]
# Para insertar el valor de una variable en una cadena, coloca la letra f justo antes de la comilla de apertura. Encierra entre llaves el nombre o los nombres de las variables que quieras usar dentro de la cadena. Python reemplazará cada variable con su valor al mostrar la cadena.
#
# Estas cadenas se denominan *f-strings*. La *f* significa *formato*, ya que Python formatea la cadena reemplazando el nombre de cualquier variable entre llaves por su valor.

# %% [markdown]
# Se pueden hacer muchas cosas con las *f-strings*. Por ejemplo, se pueden usar *f-strings* para componer mensajes completos utilizando la información asociada a una variable, como se muestra aquí:

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = f'{first_name} {last_name}'
print(f'Hola, {full_name.title()}!')
# Out:
# Hola, Ada Lovelace!

# %% [markdown]
# El nombre completo se usa en una frase que saluda al usuario, y el método `title()` cambia el nombre a formato de título. Este código devuelve un saludo sencillo pero bien formateado.
#
# También puedes usar *f-strings* para componer un mensaje y luego asignar el mensaje completo a una variable:

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = f'{first_name} {last_name}'
message = f'Hola, {full_name.title()}!'
print(message)
# Out:
# Hola, Ada Lovelace!

# %% [markdown]
# Este código también muestra el mensaje **¡Hola, Ada Lovelace!**, pero al asignar el mensaje a una variable hacemos que la llamada final a `print()` sea mucho más sencilla.

# %% [markdown]
# #### **2.2.3 Agregar Espacios en Blanco a las Cadenas con Tabulaciones o Saltos de Línea**

# %% [markdown]
# En programación, los espacios en blanco se refieren a cualquier carácter no imprimible, como *espacios*, *tabulaciones* y *símbolos de fin de línea*. Puedes usar espacios en blanco para organizar tu código y facilitar su lectura.
#
# Para agregar una tabulación a su texto, utilice la combinación de caracteres `\t`:

# %%
print('Python')
print('\tPython')
# Out:
# Python
# 	Python

# %% [markdown]
# Para agregar un salto de línea en una cadena, utilice la combinación de caracteres `\n`:

# %%
print('Languages:\nPython\nC\nJavaScript')
# Out:
# Languages:
# Python
# C
# JavaScript

# %% [markdown]
# También puedes combinar tabulaciones y saltos de línea en una sola cadena. La cadena `"\n\t"` le indica a Python que pase a una nueva línea y que la siguiente comience con una tabulación. El siguiente ejemplo muestra cómo puedes usar una cadena de una sola línea para generar cuatro líneas de salida:

# %%
print('Languages:\n\tPython\n\tC\n\tJavaScript')
# Out:
# Languages:
# 	Python
# 	C
# 	JavaScript

# %% [markdown]
# #### **2.2.4 Eliminando Espacios en Blanco**

# %% [markdown]
# Los espacios en blanco adicionales pueden resultar confusos en tus programas. Para los programadores, "python" y "python ' parecen prácticamente iguales. Pero para un programa, son dos cadenas diferentes. Python detecta el espacio adicional en "python ' y lo considera significativo a menos que le indiques lo contrario.
#
# Es importante tener en cuenta los espacios en blanco, ya que a menudo se querrá comparar dos cadenas para determinar si son iguales. Los espacios en blanco adicionales también pueden resultar confusos en situaciones mucho más sencillas. Afortunadamente, Python facilita la eliminación de espacios en blanco adicionales de los datos que introducen las personas.
#
# Python puede buscar espacios en blanco adicionales a la derecha y a la izquierda de una cadena. Para asegurarse de que no existan espacios en blanco a la derecha de una cadena, utiliza el método `rstrip()`:

# %%
favorite_language = 'Python '
favorite_language
# Out:
# 'Python '

# %% [markdown]
# El valor asociado a `favorite_language` contiene un espacio en blanco adicional al final de la cadena. Al solicitar este valor a Python en una sesión de terminal, se puede observar dicho espacio.
#
# Cuando el método `rstrip()` actúa sobre la variable `favorite_language`, este espacio adicional se elimina.

# %%
# Imprimir eliminando espacios en blanco finales con rstrip()
favorite_language.rstrip()
# Out:
# 'Python'

# %% [markdown]
# Sin embargo, solo se elimina temporalmente. Si se solicita el valor de `favorite_language` nuevamente, la cadena se verá igual que cuando se ingresó, incluyendo el espacio en blanco adicional.

# %%
favorite_language
# Out:
# 'Python '

# %% [markdown]
# Para eliminar el espacio en blanco de la cadena de forma permanente, es necesario asociar el valor sin espacios en blanco con el nombre de la variable.

# %%
favorite_language = 'python '
favorite_language = favorite_language.rstrip()
favorite_language
# Out:
# 'python'

# %% [markdown]
# Para eliminar los espacios en blanco de una cadena, se eliminan de la parte derecha y se asocia este nuevo valor con la variable original. , o de ambos lados a la vez usando `strip()`.

# %%
# Cadena con espacios en blanco iniciales y finales
favorite_language = ' python '
favorite_language.rstrip() # Quitar espacios en blanco finales con rstrip()
# Out:
# ' python'

# %% [markdown]
# También se pueden eliminar los espacios en blanco de la parte izquierda de una cadena usando el método `lstrip()`

# %%
favorite_language.lstrip() # Quitar espacio en blanco iniciales con lstrip()
# Out:
# 'python '

# %% [markdown]
# O puedes eliminar los espacios en blanco de ambos lados a la vez usando `strip()`.

# %%
favorite_language.strip() # Quitar espacios iniciales y finales con strip()
# Out:
# 'python'

# %% [markdown]
# En el ejemplo anterior, partimos de un valor que contiene espacios en blanco al principio y al final. Luego, eliminamos los espacios adicionales del lado derecho, del lado izquierdo y de ambos lados. Experimentar con estas funciones de eliminación de espacios en blanco puede ayudarte a familiarizarte con la manipulación de cadenas. En la práctica, estas funciones se utilizan con mayor frecuencia para limpiar la entrada del usuario antes de almacenarla en un programa.

# %% [markdown]
# #### **2.2.5 Eliminando Prefijos**

# %% [markdown]
# Consideremos una URL con el prefijo común https://. Si se desea eliminar este prefijo para centrarnos únicamente en la parte de la URL que los usuarios deben escribir en la barra de direcciones: Introduce el nombre de la variable seguido de un punto y, a continuación, el método `removeprefix()`. Dentro de los paréntesis, introduce el prefijo que deseas eliminar de la cadena original.

# %%
Colombia_url = 'https://www.colombia.com'
Colombia_url.removeprefix('https://')
# Out:
# 'www.colombia.com'

# %%
simple_url = Colombia_url.removeprefix('https://')
print(simple_url)
# Out:
# www.colombia.com

# %% [markdown]
# #### **2.2.6 Cómo evitar errores de sintaxis con cadenas de texto**
#
# Un tipo de error con cierta frecuencia es un *error de sintaxis*, el cual ocurre cuando Python no reconoce una sección de tu programa como código Python válido.
#
# Por ejemplo, si usas un apóstrofo dentro de comillas simples, se producirá un error. Esto sucede porque Python interpreta todo lo que se encuentra entre la primera comilla simple y el apóstrofo como una cadena de texto. Luego intenta interpretar el resto del texto como código Python, lo que provoca errores.
#
# El apóstrofo aparece dentro de un par de comillas dobles, por lo que el intérprete de Python no tiene problemas para leer la cadena correctamente:

# %%
message = "Pa’lante, que los sueños no esperan."
print(message)
# Out:
# Pa’lante, que los sueños no esperan.

# %% [markdown]
# Sin embargo, si utilizas comillas simples, Python no puede identificar dónde debe terminar la cadena:

# %%
message = 'Pa'lante, que los sueños no esperan.'
print(mensaje)
# Out:
#   Cell In[22], line 1
#     message = 'Pa'lante, que los sueños no esperan.'
#                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# La función de **resaltado** de sintaxis del editor debería ayudarte a detectar rápidamente algunos errores de sintaxis mientras escribes tus programas. Si ves código Python **resaltado** como si fuera inglés, o viceversa, probablemente tengas una comilla mal colocada en alguna parte de tu archivo.

# %% [markdown]
# #### **2.2.7 Inténtalo Tú Mismo!**

# %% [markdown]
# ##### *Ejercicio 2-3. Mensaje Personal:*
#
# Usa una variable para representar el nombre de una persona e imprime un mensaje para esa persona. Tu mensaje debe ser sencillo, como por ejemplo: «Hola Sebas, ¿te gustaría aprender algo de Python hoy?».

# %%
# Ejercicio 2-3

# %% [markdown]
# ##### *Ejercicio 2-4. Nombre en mayúsculas y minúsculas:*
#
# Utilice una variable para representar el nombre de una persona y, a continuación, imprima el nombre de esa persona en minúsculas, mayúsculas y formato de título.

# %%
# Ejercicio 2-4

# %% [markdown]
# ##### *Ejercicio 2-5. Cita Famosa:*
#
# Busca una cita de una persona famosa que admires. Imprime la cita y el nombre de su autor. El resultado final debería ser similar al siguiente, incluyendo las comillas:
#
# > **Albert Einstein** dijo una vez: "Quien nunca ha cometido un error, nunca ha intentado nada nuevo".

# %%
# Ejercicio 2-5

# %% [markdown]
# ##### *Ejercicio 2-6. Cita Famosa 2:*
#
# Repite el ejercicio 2-5, pero esta vez, representa el nombre de la persona famosa con una variable llamada famous_person. Luego, escribe tu mensaje y represéntalo con una nueva variable llamada message. Imprime tu mensaje.

# %%
# Ejercicio 2-6

# %% [markdown]
# ##### *Ejercicio 2-7. Stripping Names:*
#
# Utiliza una variable para representar el nombre de una persona e incluye espacios en blanco al principio y al final del nombre.
#
# Asegúrate de usar cada combinación de caracteres, "\t" y "\n", al menos una vez.
#
# Imprime el nombre una vez para que se muestren los espacios en blanco que lo rodean. Luego, imprime el nombre utilizando cada una de las tres funciones para eliminar espacios en blanco: `lstrip()`, `rstrip()` y `strip()`.

# %%
# Ejercicio 2-7

# %% [markdown]
# ##### *Ejercicio 2-8. Extensiones de Archivo:*
#
# Python cuenta con el método `removesuffix()`, que funciona exactamente igual que `removeprefix()`. Asigna el valor `'python_notes.txt`' a una variable llamada `filename`. Luego, usa el método `removesuffix()` para mostrar el nombre del archivo sin la extensión, como hacen algunos exploradores de archivos.

# %%
# Ejercicio 2-8

# %% [markdown]
# ### **2.3 Números**
#
# En programación, los números se utilizan con frecuencia para llevar la puntuación en juegos, representar datos en visualizaciones, almacenar información en aplicaciones web, etc. Python trata los números de diversas maneras, según su uso. Primero, veamos cómo Python maneja los números enteros, ya que son los más sencillos de usar.

# %% [markdown]
# #### **2.3.1 Enteros**
# En Python puedes sumar (+), restar (-), multiplicar (*) y dividir (/) números enteros.

# %%
# Sumar enteros
2 + 3
# Out:
# 5

# %%
# Restar enteros
3 - 2
# Out:
# 1

# %%
# Multiplicación
2 * 3
# Out:
# 6

# %%
# División
3 / 2
# Out:
# 1.5

# %% [markdown]
# Python utiliza dos símbolos de multiplicación para representar exponentes:

# %%
# Exponente
3 ** 2
# Out:
# 9

# %%
3 ** 3
# Out:
# 27

# %%
10 ** 6
# Out:
# 1000000

# %% [markdown]
# Python también admite el orden de las operaciones, por lo que puedes usar varias operaciones en una misma expresión. Además, puedes usar paréntesis para modificar el orden de las operaciones, de modo que Python pueda evaluar tu expresión en el orden que especifiques. Por ejemplo:

# %%
2 + 3*4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20

# %% [markdown]
# El espaciado en estos ejemplos no afecta la forma en que Python evalúa las expresiones; simplemente ayuda a identificar más rápidamente las operaciones que tienen prioridad al leer el código.

# %% [markdown]
# #### **2.3.2 Números en Coma Flotante (Floats)**

# %% [markdown]
# #### **2.3.3 Números Enteros y en Coma Flotante**

# %% [markdown]
# #### **2.3.4 Subrayados en los Números**

# %% [markdown]
# #### **2.3.5 Asignación Múltiple**

# %% [markdown]
# #### **2.3.6 Constantes**

# %% [markdown]
# #### **2.3.7 Inténtalo Tú Mismo**

# %% [markdown]
# ### **2.4 Comentarios**

# %% [markdown]
# #### **2.4.1 Cómo se Escriben los Comentarios**

# %% [markdown]
# #### **2.4.2 ¿Qué Tipo de Comentarios Deberías Escribir?**

# %% [markdown]
# #### **2.4.3 Inténtalo Tú Mismo**

# %% [markdown]
# ### **2.5 El Zen de Python**

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# #### **2.5.1 Inténtalo Tú Mismo**
