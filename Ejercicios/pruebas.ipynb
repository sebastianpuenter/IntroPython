# %%
import pandas as pd

Datos = {
    'Nombre': ['Sebastián', 'Isabella', 'Victoria'],
    'Apellido': ['Puente Reyes', 'Puente Novoa', 'Puente Novoa'],
    'Edad': [42, 12, 6],
    'Estatura': [1.76, 1.65, 1.56]
}
print(Datos)

df = pd.DataFrame(Datos)
df
# Out:
# {'Nombre': ['Sebastián', 'Isabella', 'Victoria'], 'Apellido': ['Puente Reyes', 'Puente Novoa', 'Puente Novoa'], 'Edad': [42, 12, 6], 'Estatura': [1.76, 1.65, 1.56]}
#       Nombre      Apellido  Edad  Estatura
# 0  Sebastián  Puente Reyes    42      1.76
# 1   Isabella  Puente Novoa    12      1.65
# 2   Victoria  Puente Novoa     6      1.56
